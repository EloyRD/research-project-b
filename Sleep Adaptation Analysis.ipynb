# %% [markdown]
# # RECREATION OF PAPER

# %% [markdown]
# ## Model setup

# %%
# %matplotlib inline
from jupyterthemes import jtplot
jtplot.style()
#import seaborn as sns
#sns.set()

# %%
from agents import Animal, FoodPatch, SleepPatch
from model import SleepAnimals

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
a = np.random.choice(['feeding' , 'sleeping' , 'flexible'] , 24)
a
# Out:
# array(['flexible', 'feeding', 'sleeping', 'sleeping', 'flexible',
#        'sleeping', 'sleeping', 'flexible', 'feeding', 'flexible',
#        'sleeping', 'sleeping', 'flexible', 'sleeping', 'sleeping',
#        'flexible', 'sleeping', 'sleeping', 'flexible', 'flexible',
#        'sleeping', 'feeding', 'flexible', 'sleeping'], dtype='<U8')

# %%
ground = SleepAnimals(1, genome=a,  width=40, height=40)

# %%
# Interdistance or Manhattan distance between centers of Patches regions, 
# and intradistance or maximum Manhattan distance to center in each region
( ground.interdistance, ground.intradistance)
# Out:
# (28, 16)

# %% [markdown]
# ### Food and sleep patches location

# %%
available_spots = ground.arrayRGB_clusters()
plt.figure( figsize = (7, 7) )
plt.imshow(np.swapaxes(available_spots,0,1), origin = 'lower')
plt.plot(ground.fp_center_x, ground.fp_center_y, '+', mew=5, ms=20)
plt.plot(ground.sp_center_x, ground.sp_center_y, '+', mew=5, ms=20)

# %%
# Coordinate of center of Food Patches Region
(ground.fp_center_x, ground.fp_center_y)
# Coordinate of center of Sleep Patches Region
(ground.sp_center_x, ground.sp_center_y)
# Out:
# (10, 19)
# (29, 10)

# %% [markdown]
# ### First population of food and sleep patches

# %%
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %%
display2D = ground.array2D_display()
plt.figure( figsize = (9, 9) )
plt.imshow(display2D.T, 'afmhot_r', origin = 'lower')

# %% [markdown]
# ## Testing movement of agent

# %%
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (0, (0, 10), 5, 'TOP')

# %%
ground.step()
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (1, (1, 11), 4, 'TOP-RIGHT')

# %%
ground.step()
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (2, (2, 12), 3, 'TOP-RIGHT')

# %%
ground.step()
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (3, (3, 13), 4, 'TOP-RIGHT')

# %%
ground.step()
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (4, (4, 14), 4, 'TOP-RIGHT')

# %%
ground.step()
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (5, (4, 15), 5, 'TOP')

# %%
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %% [markdown]
# ## Testing data collection

# %%
for i in range(495):
    ground.step()

# %%
ground.schedule.time , ground.schedule.agents[0].pos , ground.schedule.agents[0].direction , ground.schedule.agents[0].lookingto
# Out:
# (500, (17, 39), 12, 'LEFT')

# %%
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %%
agents = ground.datacollector.get_agent_vars_dataframe()
Agent1_fitness = agents.xs(1, level="AgentID")
Agent1_fitness.Fitness.plot()

# %%
for i in range(3500):
    ground.step()

# %%
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %%
for i in range(3000):
    ground.step()
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %%
for i in range(3000):
    ground.step()
RGBdisplay = ground.arrayRGB_display()
plt.figure( figsize = (9, 9) )
plt.imshow(np.swapaxes(RGBdisplay,0,1), origin = 'lower')

# %%
agents = ground.datacollector.get_agent_vars_dataframe()
agent1_data = agents.xs(1, level="AgentID")
agent1_data.Fitness.plot()

# %%
agent1_data.Mode.plot()

# %%
agent1_data.Food_fitness.plot()

# %%
agent1_data.Sleep_fitness.plot()
