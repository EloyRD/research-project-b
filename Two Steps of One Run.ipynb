# %% [markdown]
# # RESEARCH PROJECT B
# ## Testing two steps of a full experiment

# %% [markdown]
# ### Setting up modules

# %%
# %matplotlib inline
from jupyterthemes import jtplot
jtplot.style()

# %%
import math
import random
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from agents import Animal, FoodPatch, SleepPatch
from model import SleepAnimals
from experiment import *

# %%
current_exp_id = 0
generation_number = 0
abm_models = []
generations = []
results = pd.DataFrame()

# %% [markdown]
# ### Creating genomes of initial population
# The array `genomes` represent the genomes of the first 100 individuals. Each gene in the genome has three possible values:
# `'flex' , 'eat' , 'sleep'`

# %%
genomes = genome_alternatives(100)
np.shape(genomes)
selected_genomes = genomes
# Out:
# (100, 24)

# %% [markdown]
# ### Agent-based model generation and execution (first generation)
# In this step, an agent-based model (for fitness evaluation) is created for each indivual and stored in the `abm_models` array.
# Considering that each model step represents one minute, we run each model for 7 days.

# %%
# %%time
for current_exp_id in range(100*generation_number + 0, 100*generation_number + 100):
    i = current_exp_id
    abm_models.append( SleepAnimals(i, genome=selected_genomes[i-100*generation_number],  width=40, height=40) )
    for j in range(60*24*7):
        abm_models[i].step()
# Out:
# Wall time: 1min 11s

# %%
# a = model[0].datacollector.get_agent_vars_dataframe()
# final_fitness = a.xs(1,level="AgentID")[]

# %% [markdown]
# Example code for accessing properties of the agent.
# `experiment_id` is the unique id of each model. (There is only one individual per model)

# %%
experiment_id = 20
abm_models[experiment_id].schedule.agents[0].fitness
abm_models[experiment_id].schedule.agents[0].fitness_food
abm_models[experiment_id].schedule.agents[0].fitness_sleep
# Out:
# 0.49999999998985495
# 0.9999999999796918
# 1.8061387908735792e-14

# %% [markdown]
# ### Data collection and evaluation of fitness of individuals
# From the `abm_models` array, a list `current_generation` is constructed in which each row consists of:
# `experiment_id , fitness of the individual on the last step, genome of the agent`
# This list is then sorted in descending order of fitness values.

# %%
current_generation = []
for i in range(100*generation_number + 0, 100*generation_number + 100):
    a = [ abm_models[i].model_id , abm_models[i].schedule.agents[0].fitness , 
         abm_models[i].schedule.agents[0].circadian_rythm ]
    current_generation.append( a )

# %%
generation_results = dataframe_generation(generation_number , current_generation)
results = results.append(generation_results)

# %%
current_generation.sort(key = lambda x : x[1], reverse=True)
generation_number += 1

# %% [markdown]
# The array `generations` will store the captured data of each generation.

# %%
generations.append( current_generation )

# %% [markdown]
# ### Evaluation of individuals and creation of new population (2nd generation)
# After the end of the first generation, the 20 fittest individuals are selected and the other 80 are discarded.
# From each one of these selected individuals, 5 new individuals are created. Thus, maintaining the population size.
# Each `gene` has a 5% chance of mutation. In case of mutation, it can take any of the other three available three gene values.

# %%
# Variables for the mutation probability and the storage of the genomes for the current
# generation. 
p = 0.05
selected_genomes = np.full( (100 , 24) , 'sleep')

# %%
# This loop assigns the gene values to the new individuals, from the most fit individuals
# in the previous generation.
# During each gene assignation, mutation can occurr with a chance of 1 mutation per every
# 20 genes.
for i in range(20):
    for j in range(5):
        for k in range(24):
            a = current_generation[i][2][k]
            a = mutation_gene( a , p )
            selected_genomes[int(100/20)*i + j] [k] = a

# %% [markdown]
# ### Simulation execution for second generation

# %%
# Reading some values
generation_number , current_exp_id
# Out:
# (1, 99)

# %% [markdown]
# Running the simulation for the whole new generation.

# %%
# %%time
for current_exp_id in range(100*generation_number + 0, 100*generation_number + 100):
    i = current_exp_id
    abm_models.append( SleepAnimals(i, genome=selected_genomes[i-100*generation_number],  width=40, height=40) )
    for j in range(60*24*7):
        abm_models[i].step()
# Out:
# Wall time: 37 s

# %% [markdown]
# Capturing data.

# %%
current_generation = []
for i in range(100*generation_number + 0, 100*generation_number + 100):
    a = [ abm_models[i].model_id , abm_models[i].schedule.agents[0].fitness , abm_models[i].schedule.agents[0].circadian_rythm ]
    current_generation.append( a )

# %%
generation_results = dataframe_generation(generation_number , current_generation)
results = results.append(generation_results)

# %%
current_generation.sort(key = lambda x : x[1], reverse=True)
generation_number += 1

# %%
generations.append( current_generation )

# %% [markdown]
# Creating new individuals

# %%
selected_genomes = np.full( (100 , 24) , 'sleep')
for i in range(20):
    for j in range(5):
        for k in range(24):
            a = current_generation[i][2][k]
            a = mutation_gene( a , p )
            selected_genomes[int(100/20)*i + j] [k] = a

# %% [markdown]
# ### Some results

# %%
generation_number , current_exp_id
# Out:
# (2, 199)

# %%
results.loc['1st'].nlargest(20,'fitness')
# Out:
#             u_id   fitness  1  2  3  4  5  6  7  8 ... 15 16 17 18 19 20 21  \
# individual                                         ...
# 097           96  0.748750  S  E  F  F  F  E  E  F ...  E  E  S  F  E  E  S
# 020           19  0.743751  S  S  F  S  E  E  E  E ...  E  S  F  S  S  F  F
# 063           62  0.743751  S  S  S  S  F  F  E  F ...  S  E  F  F  E  E  F
# 010            9  0.737510  S  S  S  F  S  S  E  F ...  E  F  E  E  E  F  F
# 054           53  0.735641  S  F  E  S  E  S  E  E ...  E  E  F  S  E  E  F
# 087           86  0.735641  S  S  S  S  S  E  E  E ...  F  S  F  F  S  E  S
# 035           34  0.735018  S  E  F  F  E  E  E  S ...  S  E  S  F  F  S  S
# 043           42  0.735018  S  E  F  F  S  S  S  F ...  S  E  S  S  S  E  S
# 036           35  0.733151  S  S  F  S  S  E  F  S ...  F  F  E  E  F  S  S
# 023           22  0.731285  S  E  S  F  S  E  S  S ...  E  E  F  E  S  E  E
# 070           69  0.727561  S  E  S  S  E  F  S  F ...  E  E  F  E  E  F  S
# 025           24  0.726321  S  F  E  S  E  F  E  F ...  E  F  E  F  E  F  F
# 089           88  0.721993  S  E  S  S  E  E  F  F ...  S  E  S  E  F  S  S
# 091           90  0.714614  S  S  E  F  F  S  E  F ...  E  S  F  F  E  F  S
# 072           71  0.709729  S  E  E  E  S  E  S  E ...  E  F  F  E  S  F  F
# 076           75  0.709729  S  S  S  E  F  E  S  E ...  E  S  E  E  E  S  S
# 050           49  0.706691  S  E  S  S  E  E  S  F ...  F  E  S  S  F  S  S
# 073           72  0.698857  S  F  F  F  F  S  S  S ...  S  S  F  S  E  S  E
# 094           93  0.692900  S  E  E  F  S  E  E  S ...  F  S  S  F  F  E  E
# 092           91  0.692308  S  F  S  F  E  F  S  F ...  E  S  S  E  F  F  E
#
#            22 23 24
# individual
# 097         F  S  S
# 020         E  E  E
# 063         S  S  S
# 010         F  F  S
# 054         F  E  E
# 087         S  F  F
# 035         E  F  F
# 043         E  S  F
# 036         E  E  F
# 023         F  F  F
# 070         F  F  E
# 025         S  S  E
# 089         F  S  E
# 091         F  S  F
# 072         F  F  F
# 076         S  E  S
# 050         S  S  F
# 073         S  S  S
# 094         E  E  S
# 092         F  S  E
#
# [20 rows x 26 columns]

# %%
results.loc['2nd'].nlargest(20,'fitness')
# Out:
#             u_id   fitness  1  2  3  4  5  6  7  8 ... 15 16 17 18 19 20 21  \
# individual                                         ...
# 005          104  0.749375  S  F  F  F  F  E  E  F ...  E  E  S  F  E  E  S
# 032          131  0.749375  S  E  F  S  E  E  E  S ...  S  E  S  F  F  S  S
# 074          173  0.749375  S  E  E  E  S  E  S  E ...  E  F  F  E  S  F  F
# 049          148  0.748750  S  E  S  F  S  E  S  S ...  E  E  F  E  S  E  E
# 066          165  0.748750  S  S  E  F  F  S  E  F ...  E  S  F  F  E  F  S
# 045          144  0.748125  S  S  F  S  S  E  F  S ...  F  F  E  E  F  S  S
# 053          152  0.748125  S  E  S  S  E  F  S  F ...  E  E  F  E  E  S  S
# 077          176  0.746875  S  S  S  E  F  E  S  E ...  E  S  E  E  E  S  S
# 064          163  0.746250  S  E  S  S  E  E  F  F ...  S  S  S  E  F  S  S
# 084          183  0.746250  S  E  F  S  E  E  S  F ...  E  E  S  E  F  S  S
# 026          125  0.745625  S  S  S  S  F  E  E  E ...  F  S  F  F  S  E  S
# 072          171  0.745625  S  E  E  E  S  E  S  E ...  E  F  F  E  S  F  F
# 016          115  0.745001  S  S  S  F  S  S  F  F ...  E  F  F  S  E  F  F
# 054          153  0.745001  S  E  S  S  E  F  S  F ...  E  E  F  E  E  F  S
# 073          172  0.745001  S  E  E  E  S  E  S  E ...  E  F  F  E  S  F  F
# 057          156  0.744376  S  F  E  S  E  F  E  F ...  E  F  E  F  E  F  F
# 093          192  0.743751  S  E  E  F  S  S  E  S ...  F  S  S  F  F  E  E
# 068          167  0.742502  S  S  E  F  F  S  E  F ...  E  S  F  F  E  F  S
# 012          111  0.741254  S  S  S  S  F  F  E  F ...  S  E  F  F  E  S  F
# 055          154  0.741254  S  E  S  S  E  F  S  F ...  E  E  F  E  E  F  S
#
#            22 23 24
# individual
# 005         F  S  S
# 032         E  F  F
# 074         F  F  F
# 049         F  F  F
# 066         E  S  F
# 045         E  E  F
# 053         F  F  E
# 077         S  E  S
# 064         F  S  E
# 084         S  S  F
# 026         S  F  F
# 072         F  F  F
# 016         F  F  S
# 054         F  F  E
# 073         F  F  F
# 057         S  S  E
# 093         E  E  S
# 068         F  E  F
# 012         S  S  S
# 055         F  F  E
#
# [20 rows x 26 columns]
